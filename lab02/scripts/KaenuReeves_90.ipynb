# %%
import pandas as pd

df = pd.read_csv('/home/dev/Downloads/query-result.csv')
df.head(10)
# Out:
#                                                movie  \
# 0   http://academy.ontotext.com/imdb/title/TheMatrix
# 1  http://academy.ontotext.com/imdb/title/BramSto...
# 2  http://academy.ontotext.com/imdb/title/TheDevi...
# 3       http://academy.ontotext.com/imdb/title/Speed
# 4  http://academy.ontotext.com/imdb/title/MyOwnPr...
# 5  http://academy.ontotext.com/imdb/title/ChainRe...
# 6  http://academy.ontotext.com/imdb/title/BillTed...
# 7  http://academy.ontotext.com/imdb/title/MuchAdo...
# 8  http://academy.ontotext.com/imdb/title/TheLast...
#
#                            movieName  commentCount
# 0                         The Matrix           313
# 1              Bram Stoker's Dracula           181
# 2               The Devil's Advocate           117
# 3                              Speed           114
# 4               My Own Private Idaho            63
# 5                     Chain Reaction            47
# 6         Bill & Ted's Bogus Journey            43
# 7             Much Ado About Nothing            41
# 8  The Last Time I Committed Suicide            12

# %%
import matplotlib.pyplot as plt

df = df.sort_values(by='commentCount', ascending=True)

plt.figure(figsize=(10, 6))
plt.barh(df['movieName'], df['commentCount'], color='steelblue')
plt.xlabel('Количество комментариев')
plt.ylabel('Фильм')
plt.title('Популярность фильмов Keanu Reeves в 90-е по числу комментариев')
plt.tight_layout()
plt.show()
